# %% [markdown]
# # File Manipulation

# %%
import os
import shutil

for root, dirs, files in os.walk("."):
    for dir in dirs:
        if dir == 'images':
            #os.rmdir(os.path.join(root, dir))
            shutil.rmtree(os.path.join(root, dir))
    #   if dir != '.git':
    #        if dir[0] == '.':
    #            os.rmdir(os.path.join(root, dir))
    #    #print(dir)

# %%
for root, dirs, files in os.walk("."):
    for filename in files:
        name_and_path = os.path.join(root, filename)
        if filename[-3:] == 'mp4':
            print(name_and_path)
        #if name_and_path[:6] != '.\.git':
        #    print(name_and_path)
            #if filename[0] == '.':
            #    os.remove(os.path.join(root, filename))
            #if filename.endswith('.ipynb'):
            #    if filename != 'file-manipulation.ipynb':
            #        print(filename)
            #        os.remove(os.path.join(root, filename))
# Out:
# .\TechnologyStudies\IntroductionToPython\avg-flowchart.mp4
# .\TechnologyStudies\IntroductionToPython\time-flowchart.mp4

# %%
#avg-flowchart
from IPython.display import YouTubeVideo
YouTubeVideo('dpBHmp6oEjs')

# %%
#time-flowchart
from IPython.display import YouTubeVideo
YouTubeVideo('1hFQ-ysdZcE')
